# %%
import tweepy

# Autenticación
# consumer_key = 'TU_CONSUMER_KEY'
# consumer_secret = 'TU_CONSUMER_SECRET'
# access_token = 'TU_ACCESS_TOKEN'
# access_token_secret = 'TU_ACCESS_TOKEN_SECRET'


bearer_token = 'AAAAAAAAAAAAAAAAAAAAABILyAEAAAAAvdcTwkJmhTHN5x4a%2Fd4MwxOmAzY%3DCE6nFm9bXUt6ITTR0GxCUYdtSjGTd3P2cGEsU2mXGuVo7Z5enx'

client = tweepy.Client(bearer_token = bearer_token)
query = 'celta de vigo'
response = client.search_recent_tweets(query = query, max_results = 10)
if response.data:
    for tweet in response.data:  
        print(f'{tweet.text}')
else:
    print(' Error al recuperar los tweets')
# Out:
# 🔴
# Rayo Vallecano vs Celta de Vigo, hoy por LaLiga: formaciones, horario y cómo ver en vivo
# Este viernes, los equipos se enfrentan por una nueva jornada del torneo español, y lo vivís por DSports. https://t.co/QwpBOvhTRa
# 🔴Rayo Vallecano vs Celta Vigo 𝐄𝐧 𝐕𝐢𝐯𝐨 𝐇𝐨𝐲 𝐏𝐚𝐫𝐭𝐢𝐝𝐨 𝟮𝟬𝟮𝟱
# 🗓10 January 2025
# 🕑02:00 AM
# 🏟Estadio de Vallecas, Madrid, Spain https://t.co/C9FA4VPpNl
# 🔴Rayo Vallecano vs Celta Vigo 𝐄𝐧 𝐕𝐢𝐯𝐨 𝐇𝐨𝐲 𝐏𝐚𝐫𝐭𝐢𝐝𝐨 𝟮𝟬𝟮𝟱
# 🗓10 January 2025
# 🕑02:00 AM
# 🏟Estadio de Vallecas, Madrid, Spain https://t.co/f0scqCEofM
# Rayo Vallecano y Celta de Vigo disputan este viernes la primera jornada del año de LaLiga con un duelo al que ambos llegan separados por solo dos puntos.
#
# ➡️ https://t.co/72L1zAmPk9
#
# #rayocelta #LaLiga https://t.co/O3xuYBWQwc
# Los aficionados del Celta siguen rabiando con el Madrid mientras su amigo culé ha reconocido que cuando era Vicepresidente de la RFEF ayudaron al Athletic para salvarse descendiendo de esta manera al Celta de Vigo que fue quien ocupó su plaza. https://t.co/5Fg0S7KXyp
# ⚡ Günün Kuponu ⚡
# 🗓️ Tarih: 10 Ocak 2025, Cuma
# 🎯 Toplam Oran: 9.70
#
# 🔸 Borussia Dortmund vs Bayer Leverkusen
# 🕚 Saat: 22:30
# 💡 Tahmin: Maç Sonucu 2 — Oran: 2.47
#
# 🔸 Lazio vs Como
# 🕚 Saat: 22:45
# 💡 Tahmin: Toplam Gol (2.5) Üst — Oran: 2.09
#
# 🔸 Rayo Vallecano vs Celta de Vigo
# 🕚… https://t.co/MJCWLTydgZ https://t.co/TuBhqA1cPc
# #Prediksi #La Liga Spanyol: #Rayo Vallecano vs #Celta de Vigo 11 Januari 2025: Skor dan Jadwal
#
# Prediksi Skor: Rayo Vallecano 1-1 Celta de Vigo
#
# https://t.co/lQkPKJqQNz https://t.co/ptHCNu9uds
# 🏟️ Günün Maçı: Rayo Vallecano vs Celta de Vigo
#
# ⏰ Tarih: 10 Ocak 2025
# 🕒 Saat: 23:00
# ⚽ Karşılaşma oranları:
#
# Rayo Vallecano: 2.66
#
# Beraberlik: 3.10
#
# Celta de Vigo: 2.97
#
# 💥 Yüksek oranlarla kazanç fırsatını kaçırma!
# 🎯 Favorinle kazanmak için hemen tahmin yap!
#
# 💳 Güvenli ve… https://t.co/ICqvHqzMRA https://t.co/jXGXxw8DPg
# ZBAHİS'DE GÜNÜN MAÇLARI!
#
# ⚽️B.Dortmund🆚Leverkusen
# ⚽️Aston Villa🆚West Ham
# ⚽️Vallecano🆚Celta Vigo
#
# #zBahis'de en yüksek oranlarla bahsini al,kazanmaya başla!
#
# zBahis ; https://t.co/tPCMZod02V https://t.co/nOnZcxywAo
# 🇪🇸 Menú de hoy en #LaLigaEASports:
# ⏰ 21:00, Rayo Vallecano - RC Celta de Vigo.
#
# 🇪🇸 Menú de hoy en #LaLigaHypermotion:
# ⏰ 20:30, Granada CF - Burgos CF. https://t.co/gBhf3lxws5
